# %% [markdown]
# # The Battle of the Neighborhoods - Report

# %% [markdown]
# **1. Introduction & Business Problem:**

# %% [markdown]
# **Problem Background**

# %% [markdown]
# London is the most densily populated city in England with over 8 million inhabitants. An incredibly diverse city and arguably the capital of Western Europe. London acts as the financial centre for the majority of Europe providing oppurtubnity and investment potential for a range of industries.

# %% [markdown]
# Because of this, however, property and living costs are amongst some of the highest in the world. Business is incredibly competitive with a huge variety of choose for commsumers. Any new business or ventures need to be extensivily reaserched, planned and backed by data. Reducing the risk and maximising potential returns.

# %% [markdown]
# **Problem Description:**

# %% [markdown]
# The city of London has a huge array of resturants, cafes and eataries from a range of cultures and cuisines such as:
# 1. British
# 2. French
# 3. American
# 4. Thai
# 5. Chinease
# 6. Indian
# 7. Italian

# %% [markdown]
# Therefore to survive with a new returant venture in London, its clear to take into account various factors when selecting a location:
# 1. Population
# 2. Demorgrphics
# 3. Footfall
# 4. Competition
# 5. Cuisine
# 6. Niches
# 7. Oversaturated Markets
#
# **Target Audience:**
#
# The objective of this report is to identify the best location to start a new resturant in the city of London. Its important to explain and using data, prove the reasoning behind the desision.
#
# **Criteria for Success**
#
# The critera for this project is to privide a sound recommendation for a new resturant based on the most popular resturants within that area.

# %% [markdown]
# **2. Data :**

# %% [markdown]
# The data for this project will be aimed at one city, London.
