# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from scipy.cluster.vq import kmeans as KMeans
from numpy import array

# %%
List_url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
source = requests.get(List_url).text

# %%
soup = BeautifulSoup(source, 'xml')

# %%
table=soup.find('table')

# %%
#dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
column_names = ['Postalcode','Borough','Neighborhood']
df = pd.DataFrame(columns = column_names)

# %%
# Search all the postcode, borough, neighborhood 
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        df.loc[len(df)] = row_data

# %%
df.head()
# Out:
#   Postalcode           Borough               Neighborhood
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df=df[df['Borough']!='Not assigned']

# %%
df[df['Neighborhood']=='Not assigned']=df['Borough']
df.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3385: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc._setitem_with_indexer(indexer, value)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-ebb47ef6992f> in <module>
# ----> 1 df[df['Neighborhood']=='Not assigned']=df['Borough']
#       2 df.head()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3365             self._setitem_frame(key, value)
#    3366         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3367             self._setitem_array(key, value)
#    3368         else:
#    3369             # set column
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3383             indexer = key.nonzero()[0]
#    3384             self._check_setitem_copy()
# -> 3385             self.loc._setitem_with_indexer(indexer, value)
#    3386         else:
#    3387             if isinstance(value, DataFrame):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     654             self.obj._consolidate_inplace()
#     655             self.obj._data = self.obj._data.setitem(indexer=indexer,
# --> 656                                                     value=value)
#     657             self.obj._maybe_update_cacher(clear=True)
#     658
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/internals/managers.py in setitem(self, **kwargs)
#     508
#     509     def setitem(self, **kwargs):
# --> 510         return self.apply('setitem', **kwargs)
#     511
#     512     def putmask(self, **kwargs):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     870
#     871         # length checking
# --> 872         check_setitem_lengths(indexer, value, values)
#     873
#     874         def _is_scalar_indexer(indexer):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py in check_setitem_lengths(indexer, value, values)
#    2532                     indexer.dtype == np.bool_ and
#    2533                     len(indexer[indexer]) == len(value)):
# -> 2534                 raise ValueError("cannot set using a list-like indexer "
#    2535                                  "with a different length than the value")
#    2536     # slice
#
# ValueError: cannot set using a list-like indexer with a different length than the value

# %%
temp_df=df.groupby('Postalcode')['Neighborhood'].apply(lambda x: "%s" % ', '.join(x))
temp_df=temp_df.reset_index(drop=False)
temp_df.rename(columns={'Neighborhood':'Neighborhood_joined'},inplace=True)

# %%
df_merge = pd.merge(df, temp_df, on='Postalcode')

# %%
df_merge.drop(['Neighborhood'],axis=1,inplace=True)

# %%
df_merge.drop_duplicates(inplace=True)

# %%
df_merge.rename(columns={'Neighborhood_joined':'Neighborhood'},inplace=True)

# %%
df_merge.head()
# Out:
#   Postalcode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df_merge.shape
# Out:
# (102, 3)

# %%
def get_geocode(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return latitude,longitude

# %%
geo_df=pd.read_csv('http://cocl.us/Geospatial_data')

# %%
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_df.rename(columns={'Postal Code':'Postalcode'},inplace=True)
geo_merged = pd.merge(geo_df, df_merge, on='Postalcode')

# %%
geo_data=geo_merged[['Postalcode','Borough', 'Latitude','Longitude']]

# %%
geo_data.head()
# Out:
#   Postalcode      Borough   Latitude  Longitude
# 0        M1B  Scarborough  43.806686 -79.194353
# 1        M1C  Scarborough  43.784535 -79.160497
# 2        M1E  Scarborough  43.763573 -79.188711
# 3        M1G  Scarborough  43.770992 -79.216917
# 4        M1H  Scarborough  43.773136 -79.239476

# %%
toronto_data=geo_data[geo_data['Borough'].str.contains("Toronto")]
toronto_data.head()
# Out:
#    Postalcode          Borough   Latitude  Longitude
# 37        M4E     East Toronto  43.676357 -79.293031
# 41        M4K     East Toronto  43.679557 -79.352188
# 42        M4L     East Toronto  43.668999 -79.315572
# 43        M4M     East Toronto  43.659526 -79.340923
# 44        M4N  Central Toronto  43.728020 -79.388790

# %%
CLIENT_ID = 'DGASSQYTY3UFWXIJZ0QNGO4ZHOCEC1PWEU4JXSSW0OVLSCP5' # your Foursquare ID
CLIENT_SECRET = 'OOTUE2XE3XH4YOVP5MJ2ZZ3252F0HR03WKN2AOFTQXY0XAEH' # your Foursquare Secret
VERSION = '20180604'

# %%
def getNearbyVenues(names, latitudes, longitudes):
    radius=500
    LIMIT=100
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_data['Borough'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# East Toronto
# East Toronto
# East Toronto
# East Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Central Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Central Toronto
# Central Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# Downtown Toronto
# West Toronto
# West Toronto
# West Toronto
# West Toronto
# West Toronto
# West Toronto
# Downtown Toronto
# East Toronto

# %%
toronto_venues.head()
# Out:
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  East Toronto              43.676357              -79.293031
# 1  East Toronto              43.676357              -79.293031
# 2  East Toronto              43.676357              -79.293031
# 3  East Toronto              43.676357              -79.293031
# 4  East Toronto              43.679557              -79.352188
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0                   Glen Manor Ravine       43.676821       -79.293942
# 1  The Big Carrot Natural Food Market       43.678879       -79.297734
# 2                 Grover Pub and Grub       43.679181       -79.297215
# 3                       Upper Beaches       43.680563       -79.292869
# 4                       MenEssentials       43.677820       -79.351265
#
#       Venue Category
# 0              Trail
# 1  Health Food Store
# 2                Pub
# 3       Neighborhood
# 4     Cosmetics Shop

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                   Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Central Toronto                     108                     108    108
# Downtown Toronto                   1202                    1202   1202
# East Toronto                        128                     128    128
# West Toronto                        154                     154    154
#
#                   Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Central Toronto              108              108             108
# Downtown Toronto            1202             1202            1202
# East Toronto                 128              128             128
# West Toronto                 154              154             154

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot.drop(['Neighborhood'],axis=1,inplace=True) 
toronto_onehot.insert(loc=0, column='Neighborhood', value=toronto_venues['Neighborhood'] )
toronto_onehot.shape
# Out:
# (1592, 234)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()
# Out:
#        Neighborhood  Afghan Restaurant   Airport  Airport Food Court  \
# 0   Central Toronto           0.000000  0.000000            0.000000
# 1  Downtown Toronto           0.000832  0.000832            0.000832
# 2      East Toronto           0.000000  0.000000            0.000000
# 3      West Toronto           0.000000  0.000000            0.000000
#
#    Airport Gate  Airport Lounge  Airport Service  Airport Terminal  \
# 0      0.000000        0.000000         0.000000          0.000000
# 1      0.000832        0.001664         0.001664          0.001664
# 2      0.000000        0.000000         0.000000          0.000000
# 3      0.000000        0.000000         0.000000          0.000000
#
#    American Restaurant  Antique Shop  Aquarium  Art Gallery  Art Museum  \
# 0             0.018519      0.000000   0.00000     0.000000    0.000000
# 1             0.014143      0.001664   0.00416     0.009151    0.001664
# 2             0.023438      0.000000   0.00000     0.000000    0.000000
# 3             0.000000      0.000000   0.00000     0.006494    0.000000
#
#    Arts & Crafts Store  Asian Restaurant  Athletics & Sports  Auto Workshop  \
# 0             0.000000          0.009259            0.000000       0.000000
# 1             0.002496          0.006656            0.000832       0.000000
# 2             0.000000          0.000000            0.000000       0.007812
# 3             0.012987          0.019481            0.000000       0.000000
#
#    BBQ Joint  Baby Store  Bagel Shop    Bakery      Bank       Bar  \
# 
#
#    Salon / Barbershop  Sandwich Place  Scenic Lookout  Sculpture Garden  \
# 0            0.009259        0.064815        0.000000          0.000000
# 1            0.004992        0.009983        0.002496          0.001664
# 2            0.000000        0.023438        0.000000          0.000000
# 3            0.000000        0.006494        0.000000          0.000000
#
#    Seafood Restaurant  Shoe Store  Shopping Mall  Skate Park  Skating Rink  \
# 0            0.018519    0.000000        0.00000    0.000000      0.000000
# 1            0.017471    0.001664        0.00416    0.000000      0.000832
# 2            0.007812    0.000000        0.00000    0.007812      0.000000
# 3            0.000000    0.000000        0.00000    0.000000      0.000000
#
#    Smoke Shop  Smoothie Shop  Snack Place  Soup Place       Spa  Speakeasy  \
# 0    0.000000       0.000000     0.000000    0.000000  0.009259   0.000000
# 1    0.002496       0.001664     0.000832    0.001664  0.003328   0.002496
# 2    0.007812       0.000000     0.000000    0.000000  0.015625   0.000000
# 3    0.000000       0.006494     0.000000    0.000000  0.006494   0.006494
#
#    Sporting Goods Shop  Sports Bar   Stadium  Stationery Store  Steakhouse  \
# 0             0.018519    0.009259  0.000000          0.000000    0.000000
# 1             0.007488    0.000832  0.000000          0.000000    0.009983
# 2             0.000000    0.000000  0.000000          0.007812    0.007812
# 3             0.000000    0.000000  0.006494          0.000000    0.000000
#
#    Strip Club  Supermarket  Sushi Restaurant  Swim School  Taco Place  \
# 0    0.000000     0.009259          0.027778     0.009259    0.000000
# 1    0.000832     0.000832          0.013311     0.000000    0.000832
# 2    0.000000     0.000000          0.007812     0.000000    0.000000
# 3    0.000000     0.006494          0.012987     0.000000    0.000000
#
#    Tailor Shop  Taiwanese Restaurant  Tanning Salon  Tea Room  \
# 0      0.00000              0.000000       0.000000  0.000000
# 1      0.00416              0.000832       0.000832  0.009151
# 2      0.00000              0.000000       0.000000  0.000000
# 3      0.00000              0.000000       0.000000  0.006494
#
#    Thai Restaurant   Theater  Theme Restaurant  Toy / Game Store     Trail  \
# 0         0.009259  0.000000          0.000000          0.009259  0.000000
# 1         0.012479  0.010815          0.000832          0.000000  0.000832
# 2         0.007812  0.000000          0.000000          0.000000  0.015625
# 3         0.012987  0.006494          0.000000          0.000000  0.000000
#
#    Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0       0.000000                       0.009259          0.000000
# 1       0.002496                       0.009983          0.001664
# 2       0.000000                       0.000000          0.000000
# 3       0.000000                       0.019481          0.000000
#
#    Video Store  Vietnamese Restaurant  Wine Bar  Wings Joint  Women's Store  \
# 0     0.000000               0.009259  0.000000     0.000000       0.000000
# 1     0.000832               0.003328  0.004992     0.001664       0.000832
# 2     0.000000               0.000000  0.007812     0.000000       0.000000
# 3     0.000000               0.006494  0.006494     0.000000       0.000000
#
#    Yoga Studio
# 0     0.009259
# 1     0.005824
# 2     0.023438
# 3     0.012987

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0   Central Toronto           Coffee Shop        Sandwich Place
# 1  Downtown Toronto           Coffee Shop                  Café
# 2      East Toronto      Greek Restaurant           Coffee Shop
# 3      West Toronto                  Café                   Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Café                  Park           Pizza Place
# 1            Restaurant   Japanese Restaurant                 Hotel
# 2               Brewery                  Café    Italian Restaurant
# 3           Coffee Shop    Italian Restaurant            Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0          Dessert Shop            Restaurant                   Pub
# 1    Italian Restaurant                Bakery    Seafood Restaurant
# 2                  Park        Ice Cream Shop            Restaurant
# 3        Breakfast Spot                Bakery             Gift Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Sushi Restaurant         Clothing Store
# 1                   Gym                   Park
# 2  Fast Food Restaurant         Sandwich Place
# 3                  Park          Grocery Store

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = Kmeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-8ae2a9f48f23> in <module>
#       5
#       6 # run k-means clustering
# ----> 7 kmeans = Kmeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)
#       8
#       9 # check cluster labels generated for each row in the dataframe
#
# NameError: name 'Kmeans' is not defined
